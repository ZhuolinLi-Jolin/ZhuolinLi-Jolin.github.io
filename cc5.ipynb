# %%
import requests
import pandas as pd

url = "https://en.wikipedia.org/wiki/List_of_largest_cities"
headers = {"User-Agent": "Mozilla/5.0"}
resp = requests.get(url, headers=headers)
resp.raise_for_status()

# %%
tables_from_webpage = pd.read_html(resp.text)
df = tables_from_webpage[1]
df.head(9)
# Out:
# C:\Users\lzl\AppData\Local\Temp\ipykernel_9032\1983214428.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables_from_webpage = pd.read_html(resp.text)
#      City[a]      Country UN 2025 population estimates[11]  \
#      City[a]      Country UN 2025 population estimates[11]
# 0    Jakarta    Indonesia                         41913860
# 1      Dhaka   Bangladesh                         36585479
# 2      Tokyo        Japan                         33412512
# 3      Delhi        India                         30222405
# 4   Shanghai        China                         29558908
# 5  Guangzhou        China                         27563372
# 6      Cairo        Egypt                         25566102
# 7     Manila  Philippines                         24735305
# 8    Kolkata        India                         22549738
#
#                City proper[b]                                         \
#                    Definition Population Area (km2)   Density (/km2)
# 0              Special region   10154134        664      15,292 [13]
# 1                Capital city   10295407        338  30,460 [15][16]
# 2       Metropolis prefecture   13515271       2191       6,169 [18]
# 3  National Capital Territory   16753235       1484      11,289 [20]
# 4                Municipality   24870895       6341   3,922 [22][23]
# 5       City (sub-provincial)   18676605       7434       2,512 [22]
# 6           Urban governorate   10044894       3085       3,256 [24]
# 7                Capital city    1780148         43      41,399 [25]
# 8       Municipal corporation    4496694        206      21,829 [26]
#
#   Urban area[12]                           Metropolitan area[c]             \
#       Population Area (km2) Density (/km2)           Population Area (km2)
# 0       33756000       3546      9,519 [d]             33430285       7063
# 1       19134000        619          30911      14,543,124 [17]       —N/a
# 2       37785000       8231      4,591 [e]             37274000      13452
# 3       32226000       2344     13,748 [f]             29000000       3483
# 4       24073000       4333      5,556 [g]                 —N/a       —N/a
# 5       26940000       4535      5,940 [h]                 —N/a       —N/a
# 6       20296000       2010          10098                 —N/a       —N/a
# 7       24922000       1911     13,041 [i]             12877253        620
# 8       21747000       1352          16085             15333000       1887
#
#
#   Density (/km2)
# 0     4,733 [14]
# 1           —N/a
# 2     2,771 [19]
# 3     8,326 [21]
# 4           —N/a
# 5           —N/a
# 6           —N/a
# 7    20,770 [25]
# 8     8,126 [27]
